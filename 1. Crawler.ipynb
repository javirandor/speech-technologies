# %% [markdown]
# # Web scraper to retrieve information from CORELE corpus
# #### IMPORTANT: If you are about to use this corpus, you first need to ask for permissions to corpus responsible
#
# They are working on making the audios and transcription easily accessible and this may imply changing the website structure. This code is working on May 12th.
#
# It will access all the available interviews, download their audio files and extract sentences for the interviewed non-native speakers if and only if they have independent time markers for beggining and end of the sentence.

# %%
import requests
from xml.etree import ElementTree
import re
import time
import json

# %%
main = requests.get("http://cartago.lllf.uam.es/corele/corpus_es.html")

# %%
main_root = ElementTree.fromstring(main.content)

# %%
# Obtain all interviews and their URLs
urls = []
for child in main_root.iter('{http://www.w3.org/1999/xhtml}a'):
    if (child.get('href').startswith('./interviews')):
        urls.append(child.get('href').replace('./', 'http://cartago.lllf.uam.es/corele/'))

# %%
def get_tree (url):
    resp = requests.get(url)
    return ElementTree.fromstring(resp.content)

# %%
def get_audio_file (root):
    for child in root.iter():
        if (child.tag == '{http://www.w3.org/1999/xhtml}object'):
            audio_url = child.get('data').replace('dewplayer.swf?mp3=../', 'http://cartago.lllf.uam.es/corele/interviews/').replace('&showtime=1', '')
            audio_file = requests.get(audio_url)
            print('Getting audio from {} with name {}'.format(audio_url, audio_file))
            interview_name = audio_url.replace('http://cartago.lllf.uam.es/corele/interviews/MP3/', '')
            open('./audios/{}'.format(interview_name), 'wb').write(audio_file.content)
            return interview_name

# %%
def obtain_sentences (root):
    time_pattern = re.compile("[0-9]{1,2}\:[0-9]{2}")
    sentences = []

    current_dict = {"start_time": '0:00',
                    "end_time": '0:00',
                    "num_sentences": 0,
                    "sentences": []}

    for child in root.iter():   
        
        if child.text:
            if (child.tag=='{http://www.w3.org/1999/xhtml}span' and time_pattern.match(child.text)):
                if (current_dict['num_sentences']):
                    current_dict['end_time'] = child.text.replace('\n', '')
                    sentences.append(current_dict)

                current_dict = {"start_time": child.text.replace('\n', ''),
                           "num_sentences": 0,
                           "sentences": []}

            elif (child.tag == '{http://www.w3.org/1999/xhtml}p'):
                current_dict['num_sentences']+=1
                current_dict['sentences'].append(child.text.replace('\n', ''))

    return sentences

# %%
def filter_sentences (sentences: list):
    filtered_sentences = []

    for s in sentences:
        save = True
        for i in s['sentences']:
            if (i.startswith('*ENT')):
                save=False
        if (save):
            filtered_sentences.append(s)
    
    return filtered_sentences

# %%
def store_sentences (sentences, interview_name):
    print('Dumping transcription for {}'.format(interview_name))
    with open('./transcriptions/{}.json'.format(interview_name), 'w') as f:
        json.dump(sentences, f)

# %%
def get_interview (root):
    interview_name = get_audio_file(root)
    print('Getting {}'.format(interview_name))
    sentences = obtain_sentences(root)
    filtered_sentences = filter_sentences(sentences)
    store_sentences(filtered_sentences, interview_name)

# %%
roots = []

for url in urls:
    print("Visiting [{}/{}]: {}".format(urls.index(url), len(urls), url))
    roots.append(get_tree(url))
    time.sleep(2)
# Out:
# Visiting [0/40]: http://cartago.lllf.uam.es/corele/interviews/ES/PORMA2.html
# Visiting [1/40]: http://cartago.lllf.uam.es/corele/interviews/ES/PORWA2_1.html
# Visiting [2/40]: http://cartago.lllf.uam.es/corele/interviews/ES/PORWA2_2.html
# Visiting [3/40]: http://cartago.lllf.uam.es/corele/interviews/ES/PORWB1.html
# Visiting [4/40]: http://cartago.lllf.uam.es/corele/interviews/ES/
# Visiting [37/40]: http://cartago.lllf.uam.es/corele/interviews/ES/HUNWA2.html
# Visiting [38/40]: http://cartago.lllf.uam.es/corele/interviews/ES/KORWB1.html
# Visiting [39/40]: http://cartago.lllf.uam.es/corele/interviews/ES/TURWB1.html

# %%
for root in roots:
    print('Visiting {}/{}'.format(roots.index(root), len(roots)))
    try:
        get_interview(root)
    except:
        print('ERROR FOR INDEX {}'.format(roots.index(root)))
    time.sleep(1)
# Out:
# Visiting 0/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/PORMA2.mp3 with name <Response [200]>
# Getting PORMA2.mp3
# Dumping transcription for PORMA2.mp3
# Visiting 1/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/PORWA2_1.mp3 with name <Response [200]>
# Getting PORWA2_1.mp3
# Dumping transcription for PORWA2_1.mp3
# Visiting 2/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/PORWA2_2.mp3 with name <Response [200]>
# Getting PORWA2_2.mp3
# Dumping transcription for PORWA2_2.mp3
# Visiting 3/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/PORWB1.mp3 with name <Response [200]>
# Getting PORWB1.mp3
# Dumping transcription for PORWB1.mp3
# Visiting 4/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ITAMA2.mp3 with name <Response [200]>
# Getting ITAMA2.mp3
# Dumping transcription for ITAMA2.mp3
# Visiting 5/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ITAWA2.mp3 with name <Response [200]>
# Getting ITAWA2.mp3
# Dumping transcription for ITAWA2.mp3
# Visiting 6/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ITAMB1.mp3 with name <Response [200]>
# Getting ITAMB1.mp3
# Dumping transcription for ITAMB1.mp3
# Visiting 7/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ITAWB1.mp3 with name <Response [200]>
# Getting ITAWB1.mp3
# Dumping transcription for ITAWB1.mp3
# Visiting 8/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/FREMA2.mp3 with name <Response [200]>
# Getting FREMA2.mp3
# Dumping transcription for FREMA2.mp3
# Visiting 9/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/FREWA2.mp3 with name <Response [200]>
# Getting FREWA2.mp3
# Dumping transcription for FREWA2.mp3
# Visiting 10/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/FREMB1.mp3 with name <Response [200]>
# Getting FREMB1.mp3
# Dumping transcription for FREMB1.mp3
# Visiting 11/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/FREWB1.mp3 with name <Response [200]>
# Getting FREWB1.mp3
# Dumping transcription for FREWB1.mp3
# Visiting 12/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/CHIWA2_1.mp3 with name <Response [200]>
# Getting CHIWA2_1.mp3
# Dumping transcription for CHIWA2_1.mp3
# Visiting 13/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/CHIWA2_2.mp3 with name <Response [200]>
# Getting CHIWA2_2.mp3
# Dumping transcription for CHIWA2_2.mp3
# Visiting 14/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/CHIMB1.mp3 with name <Response [200]>
# Getting CHIMB1.mp3
# Dumping transcription for CHIMB1.mp3
# Visiting 15/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/CHIWB1.mp3 with name <Response [200]>
# Getting CHIWB1.mp3
# Dumping transcription for CHIWB1.mp3
# Visiting 16/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/JAPWA2.mp3 with name <Response [200]>
# Getting JAPWA2.mp3
# Dumping transcription for JAPWA2.mp3
# Visiting 17/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/JAPWB1_1.mp3 with name <Response [200]>
# Getting JAPWB1_1.mp3
# Dumping transcription for JAPWB1_1.mp3
# Visiting 18/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/JAPWB1_2.mp3 with name <Response [200]>
# Getting JAPWB1_2.mp3
# Dumping transcription for JAPWB1_2.mp3
# Visiting 19/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/JAPWB1_3.mp3 with name <Response [200]>
# Getting JAPWB1_3.mp3
# Dumping transcription for JAPWB1_3.mp3
# Visiting 20/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ENGWA2.mp3 with name <Response [200]>
# Getting ENGWA2.mp3
# Dumping transcription for ENGWA2.mp3
# Visiting 21/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ENGMB1.mp3 with name <Response [200]>
# Getting ENGMB1.mp3
# Dumping transcription for ENGMB1.mp3
# Visiting 22/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ENGWB1_1.mp3 with name <Response [200]>
# Getting ENGWB1_1.mp3
# Dumping transcription for ENGWB1_1.mp3
# Visiting 23/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/ENGWB1_2.mp3 with name <Response [200]>
# Getting ENGWB1_2.mp3
# Dumping transcription for ENGWB1_2.mp3
# Visiting 24/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/DUTMA2.mp3 with name <Response [200]>
# Getting DUTMA2.mp3
# Dumping transcription for DUTMA2.mp3
# Visiting 25/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/DUTWA2_1.mp3 with name <Response [200]>
# Getting DUTWA2_1.mp3
# Dumping transcription for DUTWA2_1.mp3
# Visiting 26/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/DUTWA2_2.mp3 with name <Response [200]>
# Getting DUTWA2_2.mp3
# Dumping transcription for DUTWA2_2.mp3
# Visiting 27/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/DUTWB1.mp3 with name <Response [200]>
# Getting DUTWB1.mp3
# Dumping transcription for DUTWB1.mp3
# Visiting 28/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/GERMA2.mp3 with name <Response [200]>
# Getting GERMA2.mp3
# Dumping transcription for GERMA2.mp3
# Visiting 29/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/GERWA2.mp3 with name <Response [200]>
# Getting GERWA2.mp3
# Dumping transcription for GERWA2.mp3
# Visiting 30/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/GERWB1_1.mp3 with name <Response [200]>
# Getting GERWB1_1.mp3
# Dumping transcription for GERWB1_1.mp3
# Visiting 31/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/GERWB1_2.mp3 with name <Response [200]>
# Getting GERWB1_2.mp3
# Dumping transcription for GERWB1_2.mp3
# Visiting 32/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/POLMA2_1.mp3 with name <Response [200]>
# Getting POLMA2_1.mp3
# Dumping transcription for POLMA2_1.mp3
# Visiting 33/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/POLMA2_2.mp3 with name <Response [200]>
# Getting POLMA2_2.mp3
# Dumping transcription for POLMA2_2.mp3
# Visiting 34/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/POLMB1.mp3 with name <Response [200]>
# Getting POLMB1.mp3
# Dumping transcription for POLMB1.mp3
# Visiting 35/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/POLWB1.mp3 with name <Response [200]>
# Getting POLWB1.mp3
# Dumping transcription for POLWB1.mp3
# Visiting 36/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/FINWA2.mp3 with name <Response [200]>
# Getting FINWA2.mp3
# Dumping transcription for FINWA2.mp3
# Visiting 37/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/HUNWA2.mp3 with name <Response [200]>
# Getting HUNWA2.mp3
# Dumping transcription for HUNWA2.mp3
# Visiting 38/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/KORWB1.mp3 with name <Response [200]>
# Getting KORWB1.mp3
# Dumping transcription for KORWB1.mp3
# Visiting 39/40
# Getting audio from http://cartago.lllf.uam.es/corele/interviews/MP3/TURWB1.mp3 with name <Response [200]>
# Getting TURWB1.mp3
# Dumping transcription for TURWB1.mp3
